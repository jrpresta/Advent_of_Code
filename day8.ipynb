# %% [markdown]
# # Day 8

# %% [markdown]
# # Puzzle 1

# %% [markdown]
# [Day 8 Challenge](https://adventofcode.com/2018/day/8)

# %%
with open('data/day8_input.txt', 'r') as f:
    tree_data = f.read()

# %%
tree_data
# Out:
# '8 11 7 3 5 5 3 4 1 6 0 9 6 5 1 6 2 4 1 4 1 3 1 1 2 3 1 1 7 0 9 1 3 1 3 9 2 2 7 3 1 1 3 1 2 3 3 1 6 0 8 4 9 3 1 8 1 9 1 3 2 3 1 1 1 2 2 3 5 3 6 1 8 0 10 7 3 4 7 5 9 1 3 5 5 1 1 1 3 3 1 3 2 1 7 0 8 4 5 4 2 1 7 4 9 3 2 2 1 2 1 1 1 5 0 11 4 8 8 3 8 4 1 3 5 3 8 2 1 1 1 1 1 1 5 1 3 2 3 7 1 6 0 6 1 6 9 2 5 2 2 1 2 2 1 1 1 9 0 9 9 9 7 1 6 4 9 3 7 3 1 2 1 1 2 2 1 1 1 6 0 8 1 7 2 7 5 8 1 9 2 3 1 3 3 2 1 2 3 3 2 3 4 3 5 1 9 0 6 1 4 8 6 6 6 3 1 1 1 1 1 3 2 1 1 6 0 11 1 8 1 6 5 2 1 8 8 5 1 3 3 1 2 3 2 1 8 0 6 4 7 9 1 1 2 2 1 2 2 1 2 3 2 1 4 3 3 2 3 6 1 6 0 11 7 5 8 1 9 2 4 9 9 4 8 3 1 1 2 2 3 1 9 0 11 3 9 3 9 6 9 5 9 1 4 1 1 1 3 3 3 2 3 1 3 1 6 0 9 5 2 4 8 1 1 4 9 3 3 3 3 3 1 1 1 5 1 2 2 1 2 1 6 7 4 5 4 3 4 1 9 0 6 9 6 4 9 1 5 2 3 2 2 3 2 1 1 1 1 7 0 10 8 3 2 6 1 2 3 8 3 4 3 1 1 2 1 2 1 1 6 0 7 1 4 9 2 7 1 9 1 2 1 1 1 3 1 5 3 3 3 7 1 6 0 11 6 5 9 8 1 1 5 4 5 1 4 2 2 1 1 3 1 1 5 0 6 3 1 5 3 5 1 1 1 2 2 1 1 8 0 7 2 6 1 5 3 2 8 1 3 1 3 2 3 2 2 4 4 4 2 4 2 5 3 7 1 9 0 8 6 3 1 1 8 6 2 7 3 1 2 1 1 1 3
# ...

# %%
test = '2 3 0 3 10 11 12 1 1 0 1 99 2 1 1 2'

# %%
test = test.split()

# %%
test = [int(el) for el in test]

# %%
class tree:
    def __init__(self, header):
        self.header = header
        self.childnodes = []
        self.metadata = []

def super_func(list_position):
    print(list_position)
    node = tree((test[list_position], test[list_position+1]))
    list_position += 2
    
    for i in range(node.header[0]):
        list_position, sub_node = super_func(list_position)
        node.childnodes += [super_func(list_position)]
#         list_position += 1
    
#     for i in range(node.header[1]):
#         node.metadata += [test[i+list_position]]
    return list_position, node

# %%
yo = super_func(0)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-ea80514cb0a9> in <module>
# ----> 1 yo = super_func(0)
#
# <ipython-input-62-808bcf324673> in super_func(list_position)
#      12     for i in range(node.header[0]):
#      13         list_position, sub_node = super_func(list_position)
# ---> 14         node.childnodes += [super_func(list_position)]
#      15 #         list_position += 1
#      16
#
# <ipython-input-62-808bcf324673> in super_func(list_position)
#      11
#      12     for i in range(node.header[0]):
# ---> 13         list_position, sub_node = super_func(list_position)
#      14         node.childnodes += [super_func(list_position)]
#      15 #         list_position += 1
#
# <ipython-input-62-808bcf324673> in super_func(list_position)
#      11
#      12     for i in range(node.header[0]):
# ...

# %%
yo.childnodes[0].metadata
# Out:
# [10, 11, 12]

# %%
yo.childnodes[1].metadata
# Out:
# [10, 11, 12]

# %%
yo.childnodes[0].childnodes
# Out:
# []
